# %% [markdown]
# #### Read a single part of the database as .npy file

# %%
import numpy as np

my_array = np.load('chunk_00.npy')

print(f"Shape: {my_array.shape}, Type: {my_array.dtype}")
my_array
# Out:
# Shape: (2334,), Type: <U72
# array(['a', 'a-', 'a2 level', ..., 'amuse', 'amuse-bouche', 'amusedly'],
#       shape=(2334,), dtype='<U72')
