# %%
import numpy as np

# Load the file
data = np.load('resulting_dictionary_part0.npy', allow_pickle=True)

f"Shape: {data.shape}"
# Out:
# 'Shape: (1747,)'

# %%
f"Data Type: {data.dtype}"
# Out:
# 'Data Type: object'

# %%
data[369]
# Out:
# {'word': 'acerbic',
#  'phonetic': '/əˈsɜː(ɹ)bɪk/',
#  'phonetics': [{'text': '/əˈsɜː(ɹ)bɪk/', 'audio': ''},
#   {'text': '/əˈsɜ(ɹ)bɪk/', 'audio': ''}],
#  'meanings': [{'partOfSpeech': 'adjective',
#    'definitions': [{'definition': 'Tasting sour or bitter.',
#      'synonyms': [],
#      'antonyms': []},
#     {'definition': 'Sharp, harsh, biting.', 'synonyms': [], 'antonyms': []}],
#    'synonyms': ['acrid',
#     'acrimonious',
#     'scathing',
#     'acerb',
#     'acrid',
#     'acrimonious'],
#    'antonyms': []}],
#  'license': {'name': 'CC BY-SA 3.0',
#   'url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#  'sourceUrls': ['https://en.wiktionary.org/wiki/acerbic']}
